# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.ticker as mtick
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '' # TODO: download train data and supply path here 
y, tX, ids = load_csv_data("../data/train.csv")

# %%
train_df = pd.read_csv("../data/train.csv")

# %%
train_df
# Out:
#             Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# 0       100000          s       138.470                       51.655
# 1       100001          b       160.937                       68.768
# 2       100002          b      -999.000                      162.172
# 3       100003          b       143.905                       81.417
# 4       100004          b       175.864                       16.915
# ...        ...        ...           ...                          ...
# 249995  349995          b      -999.000                       71.989
# 249996  349996          b      -999.000                       58.179
# 249997  349997          s       105.457                       60.526
# 249998  349998          b        94.951                       19.362
# 249999  349999          b      -999.000                       72.756
#
#         DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# ...

# %%
y = train_df["Prediction"]
train_y =  []
for label in y:
    if label == "s":
        train_y.append(1)
    else:
        train_y.append(0)
        
train_y = pd.DataFrame(train_y, columns=["label"])
train_y
# Out:
#         label
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 249995      0
# 249996      0
# 249997      1
# 249998      0
# 249999      0
#
# [250000 rows x 1 columns]

# %%
columns = train_df.columns[2:]
columns
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt'],
#       dtype='object')

# %%
for column in columns:
    df_und = train_df[train_df[column] != -999.0].copy()
    df = train_df[train_df[column] != -999.0].copy()
    print(column)
    df[[column]].plot()
    plt.ylim(ymin=0)
    plt.show()
    max = df[column].max()
    min = df[column].min()
    mid = df[column].median()
    print("Split on median:")
    df_binned = df.copy()
    df_binned[column] = pd.cut(df[column],bins=[min, mid, max],labels=['below median','above median'])
    df_binned[[column, "Prediction"]].groupby([column,'Prediction']).size().unstack().plot(kind='bar',stacked=True)
    plt.ylim(ymin=0)
    plt.show()
    value = df[column].value_counts().argmax()
    if len(df_und[df_und[column] == value]) > len(df_und)/10:
        print("not", value,"/", value)
        df_binned = df.copy()
        df_binned[column] = pd.cut(df_und[column],bins=[-0.00001, 0.00001, max],labels=[value, "not {}".format(value)])
        df_binned[[column, "Prediction"]].groupby([column,'Prediction']).size().unstack().plot(kind='bar',stacked=True)
        plt.ylim(ymin=0)
        plt.show()
    """
    print("Undefined / defined:")
    df_und[column] = pd.cut(df_und[column],bins=[-1000, -998, max],labels=['undefined','defined'])
    df_und[[column, "Prediction"]].groupby([column,'Prediction']).size().groupby(level=0).apply(lambda x: 100 * x / x.sum()).unstack().plot(kind='bar',stacked=True)
    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
    plt.ylim(ymin=0)
    plt.show()
    """
    print()
# Out:
# DER_mass_MMC
# Split on median:
# DER_mass_transverse_met_lep
# Split on median:
# DER_mass_vis
# Split on median:
# DER_pt_h
# Split on median:
# DER_deltaeta_jet_jet
# Split on median:
# DER_mass_jet_jet
# Split on median:
# DER_prodeta_jet_jet
# Split on median:
# DER_deltar_tau_lep
# Split on median:
# DER_pt_tot
# Split on median:
# DER_sum_pt
# Split on median:
# DER_pt_ratio_lep_tau
# Split on median:
# DER_met_phi_centrality
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     158             try:
# --> 159                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     160             except OverflowError as err:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# ...

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %% [markdown]
# ## Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '' # TODO: download train data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
OUTPUT_PATH = '' # TODO: fill in desired name of output file for submission
y_pred = predict_labels(weights, tX_test)
create_csv_submission(ids_test, y_pred, OUTPUT_PATH)
